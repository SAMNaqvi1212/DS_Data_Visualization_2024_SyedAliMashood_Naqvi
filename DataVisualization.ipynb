# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('Pak_Climate_Change_Indicators_By_HDX.csv')

# %%
df.head(5)
# Out:
#    Sno Country Name  Year  \
# 0    1     Pakistan  1960
# 1    2     Pakistan  1961
# 2    3     Pakistan  1962
# 3    4     Pakistan  1963
# 4    5     Pakistan  1964
#
#    CO2 intensity (kg per kg of oil equivalent energy use) Value  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    CO2 emissions from solid fuel consumption (kt) Value  \
# 0                                           5892.869
# 1                                           5804.861
# 2                                           6189.896
# 3                                           6681.274
# 4                                           6523.593
#
#    Cereal yield (kg per hectare) Value  \
# 0                                  NaN
# 1                                856.4
# ...

# %%
df.isnull().sum()
# Out:
# Sno                                                                                                 0
# Country Name                                                                                        0
# Year                                                                                                0
# CO2 intensity (kg per kg of oil equivalent energy use) Value                                       18
# CO2 emissions from solid fuel consumption (kt) Value                                                5
# Cereal yield (kg per hectare) Value                                                                 4
# Urban population growth (annual %) Value                                                            1
# Population growth (annual %) Value                                                                  1
# Population, total Value                                                                             0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 62 entries, 0 to 61
# Data columns (total 25 columns):
#  #   Column                                                                                           Non-Null Count  Dtype
# ---  ------                                                                                           --------------  -----
#  0   Sno                                                                                              62 non-null     int64
#  1   Country Name                                                                                     62 non-null     object
#  2   Year                                                                                             62 non-null     int64
#  3   CO2 intensity (kg per kg of oil equivalent energy use) Value                                     44 non-null     float64
#  4   CO2 emissions from solid fuel consumption (kt) Value                                             57 non-null     float64
# ...

# %%
df = df.dropna()

# %%
df.isnull().sum()
# Out:
# Sno                                                                                                0
# Country Name                                                                                       0
# Year                                                                                               0
# CO2 intensity (kg per kg of oil equivalent energy use) Value                                       0
# CO2 emissions from solid fuel consumption (kt) Value                                               0
# Cereal yield (kg per hectare) Value                                                                0
# Urban population growth (annual %) Value                                                           0
# Population growth (annual %) Value                                                                 0
# Population, total Value                                                                            0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 44 entries, 11 to 54
# Data columns (total 25 columns):
#  #   Column                                                                                           Non-Null Count  Dtype
# ---  ------                                                                                           --------------  -----
#  0   Sno                                                                                              44 non-null     int64
#  1   Country Name                                                                                     44 non-null     object
#  2   Year                                                                                             44 non-null     int64
#  3   CO2 intensity (kg per kg of oil equivalent energy use) Value                                     44 non-null     float64
#  4   CO2 emissions from solid fuel consumption (kt) Value                                             44 non-null     float64
# ...

# %%
# Filter years for cleaner plots
years = df['Year']

# %%
# CO2 Emissions from different sources (solid fuel, liquid fuel)
plt.figure(figsize=(12, 6))
plt.plot(years, df['CO2 emissions from solid fuel consumption (kt) Value'], label='Solid Fuel', color='red')
plt.plot(years, df['CO2 emissions from liquid fuel consumption (kt) Value'], label='Liquid Fuel', color='blue')
plt.xlabel('Year')
plt.ylabel('CO2 Emissions (kt)')
plt.title('CO2 Emissions from Different Sources Over Years')
plt.legend()
plt.grid(True)
plt.show()

# %%
# Population Growth trends
plt.figure(figsize=(12, 6))
plt.plot(years, df['Population growth (annual %) Value'], label='Population Growth (Annual %)', color='green')
plt.plot(years, df['Urban population growth (annual %) Value'], label='Urban Population Growth (Annual %)', color='orange')
plt.xlabel('Year')
plt.ylabel('Growth Rate (%)')
plt.title('Population Growth Trends Over Years')
plt.legend()
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(12, 6))
plt.bar(years, df['Population growth (annual %) Value'], color='blue', label='Population Growth (Annual %)')
plt.xlabel('Year')
plt.ylabel('Growth Rate (%)')
plt.title('Annual Population Growth Over Years')
plt.legend()
plt.grid(True)
plt.show()

# %%
# Scatter Plot: Annual Population Growth vs CO2 Emissions
plt.figure(figsize=(12, 6))
plt.scatter(df['Population growth (annual %) Value'], 
            df['CO2 emissions from solid fuel consumption (kt) Value'],
            label='CO2 Emissions vs Urban Population Growth',
            color='teal')
plt.xlabel('Annual Population Growth (Annual %)')
plt.ylabel('CO2 Emissions from Solid Fuel (kt)')
plt.title('Annual Population Growth vs CO2 Emissions')
plt.legend()
plt.grid(True)
plt.show()

# %%
# Rainfall Patterns
plt.figure(figsize=(12, 6))
plt.plot(years, df['RainFall Mean ()'], label='Mean Annual Rainfall', color='blue')
plt.xlabel('Year')
plt.ylabel('Rainfall (mm)')
plt.title('Mean Annual Rainfall Over Years')
plt.legend()
plt.grid(True)
plt.show()

# %%
# Cereal Yield trends
plt.figure(figsize=(12, 6))
plt.plot(years, df['Cereal yield (kg per hectare) Value'], label='Cereal Yield (kg/ha)', color='purple')
plt.xlabel('Year')
plt.ylabel('Cereal Yield (kg/ha)')
plt.title('Cereal Yield Over Years')
plt.legend()
plt.grid(True)
plt.show()
